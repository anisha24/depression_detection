# %%
for i in range(401,493):
  s = "https://dcapswoz.ict.usc.edu/wwwdaicwoz/" + str(i) + "_P.zip"
  # !wget {s}
# Out:
# --2023-02-18 16:48:19--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/401_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 481070707 (459M) [application/zip]
# Saving to: ‘401_P.zip’
#
# 401_P.zip           100%[===================>] 458.78M  6.14MB/s    in 67s
#
# 2023-02-18 16:49:27 (6.82 MB/s) - ‘401_P.zip’ saved [481070707/481070707]
#
# --2023-02-18 16:49:27--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/402_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 418293984 (399M) [application/zip]
# Saving to: ‘402_P.zip’
#
# 402_P.zip           100%[===================>] 398.92M  12.3MB/s    in 45s
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
#os.chdir('/content/drive/My Drive/ICAIML_Project/Datasets')
os.chdir('/content/')
# !mv *.zip "/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz"
# !cd "/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz')

# %%
# !mkdir train_data
# !mkdir test_data
# !mkdir dev_data

# %%
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
# 300_P.zip  340_P.zip  381_P.zip  423_P.zip  464_P.zip
# 301_P.zip  341_P.zip  382_P.zip  424_P.zip  465_P.zip
# 302_P.zip  343_P.zip  383_P.zip  425_P.zip  466_P.zip
# 303_P.zip  344_P.zip  384_P.zip  426_P.zip  467_P.zip
# 304_P.zip  345_P.zip  385_P.zip  427_P.zip  468_P.zip
# 305_P.zip  346_P.zip  386_P.zip  428_P.zip  469_P.zip
# 306_P.zip  347_P.zip  387_P.zip  429_P.zip  470_P.zip
# 307_P.zip  348_P.zip  388_P.zip  430_P.zip  471_P.zip
# 308_P.zip  349_P.zip  389_P.zip  431_P.zip  472_P.zip
# 309_P.zip  350_P.zip  390_P.zip  432_P.zip  473_P.zip
# 310_P.zip  351_P.zip  391_P.zip  433_P.zip  474_P.zip
# 311_P.zip  352_P.zip  392_P.zip  434_P.zip  475_P.zip
# 312_P.zip  353_P.zip  393_P.zip  435_P.zip  476_P.zip
# 313_P.zip  354_P.zip  395_P.zip  436_P.zip  477_P.zip
# 314_P.zip  355_P.zip  396_P.zip  437_P.zip  478_P.zip
# 315_P.zip  356_P.zip  397_P.zip  438_P.zip  479_P.zip
# 316_P.zip  357_P.zip  399_P.zip  439_P.zip  480_P.zip
# ...

# %%
dev = np.array(pd.read_csv('/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz/dev_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]

# %%
test = np.array(pd.read_csv('/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz/full_test_split.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
train = np.array(pd.read_csv('/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz/train_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]

# %%
os.chdir('/content/drive/My Drive/ICAIML_Project/Datasets/diacwoz')

# %%
# !ls
# Out:
# 300_P.zip  340_P.zip  381_P.zip  423_P.zip  464_P.zip
# 301_P.zip  341_P.zip  382_P.zip  424_P.zip  465_P.zip
# 302_P.zip  343_P.zip  383_P.zip  425_P.zip  466_P.zip
# 303_P.zip  344_P.zip  384_P.zip  426_P.zip  467_P.zip
# 304_P.zip  345_P.zip  385_P.zip  427_P.zip  468_P.zip
# 305_P.zip  346_P.zip  386_P.zip  428_P.zip  469_P.zip
# 306_P.zip  347_P.zip  387_P.zip  429_P.zip  470_P.zip
# 307_P.zip  348_P.zip  388_P.zip  430_P.zip  471_P.zip
# 308_P.zip  349_P.zip  389_P.zip  431_P.zip  472_P.zip
# 309_P.zip  350_P.zip  390_P.zip  432_P.zip  473_P.zip
# 310_P.zip  351_P.zip  391_P.zip  433_P.zip  474_P.zip
# 311_P.zip  352_P.zip  392_P.zip  434_P.zip  475_P.zip
# 312_P.zip  353_P.zip  393_P.zip  435_P.zip  476_P.zip
# 313_P.zip  354_P.zip  395_P.zip  436_P.zip  477_P.zip
# 314_P.zip  355_P.zip  396_P.zip  437_P.zip  478_P.zip
# 315_P.zip  356_P.zip  397_P.zip  438_P.zip  479_P.zip
# 316_P.zip  357_P.zip  399_P.zip  439_P.zip  480_P.zip
# ...

# %%
for i in range(len(dev)):
      s = str(int(dev[i][0])) + "_P.zip"
      # !unzip -q {s} -d dev_data
for i in range(len(test)):
      s = str(int(test[i][0])) + "_P.zip"
      # !unzip -q {s} -d test_data
for i in range(len(train)):
      s = str(int(train[i][0])) + "_P.zip"
      # !unzip -q {s} -d train_data
# Out:
# replace dev_data/302_AUDIO.wav? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_CLNF_AUs.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_CLNF_features.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_CLNF_features3D.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_CLNF_gaze.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_CLNF_hog.bin? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# y
# replace dev_data/302_CLNF_pose.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace dev_data/302_COVAREP.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_FORMANT.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace dev_data/302_TRANSCRIPT.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
